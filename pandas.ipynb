# %% [markdown]
# <a href="https://colab.research.google.com/github/Juanitam06/pandas_1/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

# %% [markdown]
# ##Crear una serie
#   Serie: arreglo unidimensional/columna de un data frame

# %%
miSerie= pd.Series([34,56,78,23,34])
miSerie
# Out:
# 0    34
# 1    56
# 2    78
# 3    23
# 4    34
# dtype: int64

# %% [markdown]
# # Diccionarios en Python
# Estructura que guarda datos en forma de objetos llave - valor, se pueden utilizar para crear dataframes.

# %%
miDiccionario={
    "nombre": "Casa1",
    "area": 120,
    "baños": 3,
    "propietarios": [
        "Paulo", "Diana", "Sonia"
    ],
    "barrio":{
        "nombre": "Gran Britalia",
        "localidad": "Bosa"}
}
miDiccionario
# Out:
# {'nombre': 'Casa1',
#  'area': 120,
#  'baños': 3,
#  'propietarios': ['Paulo', 'Diana', 'Sonia'],
#  'barrio': {'nombre': 'Gran Britalia', 'localidad': 'Bosa'}}

# %% [markdown]
# #Dataframes
# Estructura de datos en formato tabla.
# La forma mas simple de crear un dataframe es a partir de un diccionario, otra forma puede ser desde hojas de calculo, desde archivos JSON o desde archivos **CSV(valores separados por coma)**

# %%
miDtaframe= pd.DataFrame({'SI':[10,15], 'NO':[50,68]})
miDtaframe
# Out:
#    SI  NO
# 0  10  50
# 1  15  68

# %% [markdown]
# **Clase 24/04**
# Otro dataframe

# %%
encuesta= pd.DataFrame(
    {
        "Julia": ["Me gusto", "Fue horrible"],
        "Pedro": ["Fue delicioso", "No estuvo mal"]
    },
    index=["Restaurante 1", "Restaurante 2"] #nombrar los indices
)
encuesta
# Out:
#                       Julia          Pedro
# Restaurante 1      Me gusto  Fue delicioso
# Restaurante 2  Fue horrible  No estuvo mal

# %%
#ABRIR ARCHIVO

miCSV= pd.read_csv("/datos.csv")
miCSV.shape
miCSV.head()
# Out:
#    Estudiante_1   Estudiante_2   Estudiante_3
# 0            34             23             45
# 1            45             10             46
# 2            25             30             46

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
miTitanic= pd.read_csv("/content/titanic.csv")
miTitanic.shape
miTitanic.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1

# %%
electricidadCSV= pd.read_csv("/content/electricity-consumption-india-city-level-2017-19.csv")
electricidadCSV.shape
electricidadCSV.head()
# Out:
#                                               City      Year  \
# 0                                         Agartala   2018-19
# 1                                              Agra  2017-18
# 2                                            Aizawl  2018-19
# 3                                         Amritsar   2017-18
# 4  Aurangabad Maharashtra (Total Consumption/Month)  2017-18
#
#    Consumption of Electricity (in lakh units)-Domestic purpose  \
# 0                                             213.98
# 1                                            9772.00
# 2                                            2386.93
# 3                                            4076.09
# 4                                             275.07
#
#    Consumption of Electricity (in lakh units)-Commercial purpose  \
# 0                                              30.80
# 1                                            3811.00
# 2                                             481.15
# ...

# %%
electricidadCSV.describe() #Toma los datos estadisticos de las diferentes series
# Out:
#        Consumption of Electricity (in lakh units)-Domestic purpose  \
# count                                          46.000000
# mean                                        19821.499271
# std                                         62583.287221
# min                                            13.400000
# 25%                                           238.680000
# 50%                                           749.770000
# 75%                                          4266.173413
# max                                        344276.000000
#
#        Consumption of Electricity (in lakh units)-Commercial purpose  \
# count                                          46.000000
# mean                                         7229.419110
# std                                         22140.504997
# min                                             5.864000
# 25%                                            91.082500
# 50%                                           487.585000
# ...

# %%
#electricidadCSV.rename(columns={"Consumption of Electricity (in lakh units)-Domestic purpose":"DOMESTICO"}) #cambiar columnas, creando un nuevo dataframe
electricidadCSV.rename(columns={"Consumption of Electricity (in lakh units)-Domestic purpose":"DOMESTICO"}, inplace=True) #cambiar en el dataframe original

# %%
electricidadCSV.head()
# Out:
#                                               City      Year  DOMESTICO  \
# 0                                         Agartala   2018-19     213.98
# 1                                              Agra  2017-18    9772.00
# 2                                            Aizawl  2018-19    2386.93
# 3                                         Amritsar   2017-18    4076.09
# 4  Aurangabad Maharashtra (Total Consumption/Month)  2017-18     275.07
#
#    Consumption of Electricity (in lakh units)-Commercial purpose  \
# 0                                              30.80
# 1                                            3811.00
# 2                                             481.15
# 3                                            2131.73
# 4                                              83.97
#
#    Consumption of Electricity (in lakh units)-Industry purpose  \
# 0                                               5.94
# 1                                            2870.00
# ...

# %%
consumoDomestico= electricidadCSV["DOMESTICO"]
consumoDomestico.count()
# Out:
# 46

# %%
consumoDomestico.product()
# Out:
# 1.3587144781455822e+140

# %% [markdown]
# # Seleccionar filas especificas (Filtrar filas)

# %%
electricidadCSVFiltrado= electricidadCSV[electricidadCSV["DOMESTICO"]>0]
electricidadCSVFiltrado.count()
# Out:
# City                                                                           46
# Year                                                                           45
# DOMESTICO                                                                      46
# Consumption of Electricity (in lakh units)-Commercial purpose                  46
# Consumption of Electricity (in lakh units)-Industry purpose                    46
# Consumption of Electricity (in lakh units)-Public Water Work & Street Light    45
# Consumption of Electricity (in lakh units)-Others                              44
# Consumption of Electricity (in lakh units)-Total Consumption                   46
# dtype: int64

# %%
miTitanic= pd.read_csv("/content/titanic.csv")
miTitanic.shape
miTitanic.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1

# %%
miTitanicFiltrer= miTitanic[miTitanic['Survived']>0]
miTitanicFiltrer.count()
miTitanicFiltrer['Survived'].sum()
# Out:
# 153
